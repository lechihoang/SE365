# %% [markdown]
# # EXP_041A — Fusion Ablation: FiLM + MSE
# **Phase 4 | Fusion Upgrade**
# Research question: Does FiLM (Feature-wise Linear Modulation) improve fusion?
# - Fusion: `film` | Loss: MSE | Seed: 42 | AMP: enabled
# > ⚠️ Set BEST_IMAGE_EXP_ID and BEST_TEXT_EXP_ID in STEP 4.

# %% [markdown]
# ### STEP 1: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### STEP 2: Clone source code and install dependencies

# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 13374, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 13374 (delta 181), reused 163 (delta 102), pack-reused 13129 (from 1)
# Receiving objects: 100% (13374/13374), 873.22 MiB | 20.32 MiB/s, done.
# Resolving deltas: 100% (419/419), done.
# /content/SE365

# %% [markdown]
# ### STEP 3: Download and extract data

# %%
# !rm -rf ./data
# !cp /content/drive/MyDrive/SE365/data.zip ./data.zip
# !unzip -q data.zip
# !rm data.zip
# !ls -la ./data
# Out:
# total 1340
# drwxr-xr-x  4 root root    4096 Jun 16 09:21 .
# drwxr-xr-x 11 root root    4096 Jun 23 14:57 ..
# drwxr-xr-x  2 root root 1359872 Jun 16 09:59 image
# drwxr-xr-x  2 root root    4096 Jun 16 09:21 text

# %% [markdown]
# ### STEP 4: Configure paths — ✏️ Set Phase 2 & Phase 3 winners here

# %%
import os
DRIVE_ROOT = '/content/drive/MyDrive/SE365'  # ✏️ Change if needed
EXP_ID = 'EXP_041A_bestimage_besttext_film_mse'

BEST_IMAGE_EXP_ID = 'EXP_020B_swinb_xlmr_concat_mse'  # ✏️ Phase 2 winner
BEST_IMAGE_MODEL  = 'swin_base_patch4_window7_224'
BEST_TEXT_EXP_ID  = 'EXP_030B_bestimage_phobert_concat_mse'  # ✏️ Phase 3 winner
BEST_TEXT_MODEL   = 'vinai/phobert-base-v2'

DRIVE_EXP_PATH = f'{DRIVE_ROOT}/experiments/{EXP_ID}'
os.makedirs(DRIVE_EXP_PATH, exist_ok=True)
print(f'Artifacts: {DRIVE_EXP_PATH}')
print(f'Image: {BEST_IMAGE_MODEL} | Text: {BEST_TEXT_MODEL}')
# Out:
# Artifacts: /content/drive/MyDrive/SE365/experiments/EXP_041A_bestimage_besttext_film_mse
# Image: swin_base_patch4_window7_224 | Text: vinai/phobert-base-v2

# %% [markdown]
# ### STEP 5: Load pretrained weights

# %%
import os, shutil
os.makedirs('./checkpoints', exist_ok=True)
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_TEXT_EXP_ID}/best_model_train_text.pth', './checkpoints/best_model_train_text.pth')
print(f'Loaded text from {BEST_TEXT_EXP_ID}')
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_IMAGE_EXP_ID}/best_model_train_image.pth', './checkpoints/best_model_train_image.pth')
print(f'Loaded image from {BEST_IMAGE_EXP_ID}')
# Out:
# Loaded text from EXP_030B_bestimage_phobert_concat_mse
# Loaded image from EXP_020B_swinb_xlmr_concat_mse

# %% [markdown]
# ### STEP 6: Train

# %%
# !python main.py \
  --mode train_fusion \
  --fusion_type film \
  --text_model_name {BEST_TEXT_MODEL} \
  --image_model_name {BEST_IMAGE_MODEL} \
  --epochs 15 \
  --batch_size 16 \
  --lr 1e-5 \
  --grad_accum_steps 2 \
  --patience 5 \
  --loss_fn mse \
  --unfreeze_text_layers 1 \
  --unfreeze_image_layers 1 \
  --seed 42 \
  --use_amp \
  --exp_id EXP_041A_bestimage_besttext_film_mse \
  --exp_dir ./experiments
# Out:
# ====== MODE: TRAIN_FUSION ======
# Using device: cuda
# Seed: 42 | Experiment: EXP_041A_bestimage_besttext_film_mse
# config.json: 100% 678/678 [00:00<00:00, 2.43MB/s]
# vocab.txt: 100% 895k/895k [00:00<00:00, 97.5MB/s]
# bpe.codes: 100% 1.14M/1.14M [00:00<00:00, 109MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer.json: 100% 3.13M/3.13M [00:00<00:00, 149MB/s]
# Loaded timm processor for swin_base_patch4_window7_224
# pytorch_model.bin: 100% 540M/540M [00:03<00:00, 152MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 19175.63it/s]
# [transformers] RobertaModel LOAD REPORT from: vinai/phobert-base-v2
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.layer_norm.bias   | UNEXPECTED |
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# lm_head.bias              | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# pooler.dense.bias         | MISSING    |
# pooler.dense.weight       | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:  12% 67.2M/540M [00:02<00:00, 669MB/s]
# model.safetensors:  40% 142M/353M [00:02<00:00, 450MB/s]
# model.safetensors:  64% 225M/353M [00:02<00:00, 431MB/s]
# model.safetensors:  79% 277M/353M [00:02<00:00, 357MB/s]
# model.safetensors:  88% 311M/353M [00:02<00:00, 352MB/s]
# model.safetensors: 100% 353M/353M [00:03<00:00, 111MB/s]
# model.safetensors: 100% 540M/540M [00:04<00:00, 134MB/s]
# /content/SE365/Trainer.py:82: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.use_amp)
# 2026-06-23 14:59:14 ====== START: 2026-06-23T14:59:14.391259 ======
# 2026-06-23 14:59:14 Experiment: EXP_041A_bestimage_besttext_film_mse | Mode: train_fusion | exp_dir: ./experiments/EXP_041A_bestimage_besttext_film_mse
# Epoch 1/15:   0% 0/300 [00:00<?, ?it/s]/content/SE365/Trainer.py:121: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# Epoch 1/15:   0% 1/300 [00:02<13:23,  2.69s/it, loss=55, lr=0]/content/SE365/Trainer.py:132: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   self.scheduler.step()
# Epoch 1/15: 100% 300/300 [04:15<00:00,  1.17it/s, loss=43.1, lr=6.67e-6]
# /content/SE365/Trainer.py:151: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# 2026-06-23 15:04:00 Epoch 1/15 | Train Loss: 52.5726 | Val Loss: 41.4863 | Mean MAE: 6.0997
# 2026-06-23 15:04:00   -> MAE  | Food: 6.4695 | Price: 6.1370 | Atmos: 5.7560 | Service: 6.0463 | Overall: 6.0899
# 2026-06-23 15:04:00   -> RMSE | Food: 6.8357 | Price: 6.4645 | Atmos: 6.0505 | Service: 6.4246 | Overall: 6.3760
# 2026-06-23 15:04:00   -> R2   | Food: -7.8781 | Price: -8.3564 | Atmos: -8.4327 | Service: -7.0503 | Overall: -8.9843
# 2026-06-23 15:04:02 *** Saved best model to ./experiments/EXP_041A_bestimage_besttext_film_mse/best_model_train_fusion.pth (mean_mae=6.0997) ***
# Epoch 2/15: 100% 300/300 [04:14<00:00,  1.18it/s, loss=2.04, lr=9.97e-6]
# 2026-06-23 15:08:48 Epoch 2/15 | Train Loss: 16.2776 | Val Loss: 2.3329 | Mean MAE: 1.1874
# 2026-06-23 15:08:48   -> MAE  | Food: 1.1973 | Price: 1.2164 | Atmos: 1.2468 | Service: 1.2922 | Overall: 0.9845
# 2026-06-23 15:08:48   -> RMSE | Food: 1.5466 | Price: 1.5944 | Atmos: 1.5845 | Service: 1.6396 | Overall: 1.2509
# 2026-06-23 15:08:48   -> R2   | Food: 0.5455 | Price: 0.4308 | Atmos: 0.3531 | Service: 0.4757 | Overall: 0.6157
# 2026-06-23 15:08:51 *** Saved best model to ./experiments/EXP_041A_bestimage_besttext_film_mse/best_model_train_fusion.pth (mean_mae
15: 100% 300/300 [04:09<00:00,  1.20it/s, loss=1.14, lr=5.29e-6]
# 2026-06-23 15:37:08 Epoch 8/15 | Train Loss: 1.4836 | Val Loss: 2.2243 | Mean MAE: 1.1195
# 2026-06-23 15:37:08   -> MAE  | Food: 1.1238 | Price: 1.1783 | Atmos: 1.1789 | Service: 1.1890 | Overall: 0.9278
# 2026-06-23 15:37:08   -> RMSE | Food: 1.5133 | Price: 1.5741 | Atmos: 1.5302 | Service: 1.5787 | Overall: 1.2415
# 2026-06-23 15:37:08   -> R2   | Food: 0.5649 | Price: 0.4452 | Atmos: 0.3966 | Service: 0.5139 | Overall: 0.6215
# 2026-06-23 15:37:13 *** Saved best model to ./experiments/EXP_041A_bestimage_besttext_film_mse/best_model_train_fusion.pth (mean_mae=1.1195) ***
# Epoch 9/15: 100% 300/300 [04:20<00:00,  1.15it/s, loss=1.91, lr=4.13e-6]
# 2026-06-23 15:42:06 Epoch 9/15 | Train Loss: 1.4674 | Val Loss: 2.2694 | Mean MAE: 1.1335
# 2026-06-23 15:42:06   -> MAE  | Food: 1.1405 | Price: 1.1851 | Atmos: 1.1815 | Service: 1.2094 | Overall: 0.9510
# 2026-06-23 15:42:06   -> RMSE | Food: 1.5294 | Price: 1.5868 | Atmos: 1.5328 | Service: 1.6035 | Overall: 1.2634
# 2026-06-23 15:42:06   -> R2   | Food: 0.5556 | Price: 0.4362 | Atmos: 0.3946 | Service: 0.4985 | Overall: 0.6080
# 2026-06-23 15:42:06 No improvement for 1/5 epoch(s).
# Epoch 10/15: 100% 300/300 [04:21<00:00,  1.15it/s, loss=1.64, lr=3.02e-6]
# 2026-06-23 15:47:00 Epoch 10/15 | Train Loss: 1.4694 | Val Loss: 2.2625 | Mean MAE: 1.1311
# 2026-06-23 15:47:00   -> MAE  | Food: 1.1271 | Price: 1.1834 | Atmos: 1.1903 | Service: 1.2091 | Overall: 0.9456
# 2026-06-23 15:47:00   -> RMSE | Food: 1.5140 | Price: 1.5826 | Atmos: 1.5448 | Service: 1.6041 | Overall: 1.2577
# 2026-06-23 15:47:00   -> R2   | Food: 0.5645 | Price: 0.4392 | Atmos: 0.3851 | Service: 0.4982 | Overall: 0.6115
# 2026-06-23 15:47:00 No improvement for 2/5 epoch(s).
# Epoch 11/15: 100% 300/300 [04:20<00:00,  1.15it/s, loss=1.32, lr=2.01e-6]
# 2026-06-23 15:51:56 Epoch 11/15 | Train Loss: 1.4580 | Val Loss: 2.2748 | Mean MAE: 1.1355
# 2026-06-23 15:51:56   -> MAE  | Food: 1.1498 | Price: 1.1799 | Atmos: 1.1856 | Service: 1.2057 | Overall: 0.9566
# 2026-06-23 15:51:56   -> RMSE | Food: 1.5394 | Price: 1.5792 | Atmos: 1.5379 | Service: 1.5991 | Overall: 1.2706
# 2026-06-23 15:51:56   -> R2   | Food: 0.5497 | Price: 0.4416 | Atmos: 0.3906 | Service: 0.5013 | Overall: 0.6035
# 2026-06-23 15:51:56 No improvement for 3/5 epoch(s).
# Epoch 12/15: 100% 300/300 [04:24<00:00,  1.13it/s, loss=2.07, lr=1.17e-6]
# 2026-06-23 15:56:54 Epoch 12/15 | Train Loss: 1.4703 | Val Loss: 2.2507 | Mean MAE: 1.1282
# 2026-06-23 15:56:54   -> MAE  | Food: 1.1298 | Price: 1.1842 | Atmos: 1.1813 | Service: 1.2009 | Overall: 0.9448
# 2026-06-23 15:56:54   -> RMSE | Food: 1.5173 | Price: 1.5845 | Atmos: 1.5315 | Service: 1.5934 | Overall: 1.2575
# 2026-06-23 15:56:54   -> R2   | Food: 0.5626 | Price: 0.4379 | Atmos: 0.3957 | Service: 0.5048 | Overall: 0.6117
# 2026-06-23 15:56:54 No improvement for 4/5 epoch(s).
# Epoch 13/15: 100% 300/300 [04:21<00:00,  1.15it/s, loss=1.72, lr=5.32e-7]
# 2026-06-23 16:01:47 Epoch 13/15 | Train Loss: 1.4486 | Val Loss: 2.2596 | Mean MAE: 1.1310
# 2026-06-23 16:01:47   -> MAE  | Food: 1.1362 | Price: 1.1838 | Atmos: 1.1826 | Service: 1.2045 | Overall: 0.9482
# 2026-06-23 16:01:47   -> RMSE | Food: 1.5238 | Price: 1.5835 | Atmos: 1.5333 | Service: 1.5980 | Overall: 1.2608
# 2026-06-23 16:01:47   -> R2   | Food: 0.5588 | Price: 0.4386 | Atmos: 0.3942 | Service: 0.5020 | Overall: 0.6096
# 2026-06-23 16:01:47 No improvement for 5/5 epoch(s).
# 2026-06-23 16:01:47 Early stopping triggered after 13 epochs!
# 2026-06-23 16:01:47 ====== Final evaluation with best checkpoint ======
# 2026-06-23 16:01:48 Loaded best checkpoint from ./experiments/EXP_041A_bestimage_besttext_film_mse/best_model_train_fusion.pth
# 2026-06-23 16:02:21 Final Val Loss: 2.2243 | Mean MAE: 1.1195
# 2026-06-23 16:02:21 Metrics saved to ./experiments/EXP_041A_bestimage_besttext_film_mse/metrics.json
# 2026-06-23 16:02:21 Predictions saved to ./experiments/EXP_041A_bestimage_besttext_film_mse/predictions.csv
# 2026-06-23 16:02:21 ====== END: 2026-06-23T16:02:21.295713 ======

# %% [markdown]
# ### STEP 7: Save to Drive + print metrics

# %%
import json
# !cp -r ./experiments/$EXP_ID/* $DRIVE_EXP_PATH/

with open(f'./experiments/{EXP_ID}/metrics.json') as f:
    m = json.load(f)

print(f'\n=== {EXP_ID} Results ===')
print(f"Loss (val)   : {m['loss']:.4f}")
print()
print("             MAE      RMSE      R2")
print(f"  food     : {m['mae_food']:.4f}   {m['rmse_food']:.4f}   {m['r2_food']:.4f}")
print(f"  price    : {m['mae_price']:.4f}   {m['rmse_price']:.4f}   {m['r2_price']:.4f}")
print(f"  atmos    : {m['mae_atmos']:.4f}   {m['rmse_atmos']:.4f}   {m['r2_atmos']:.4f}")
print(f"  service  : {m['mae_service']:.4f}   {m['rmse_service']:.4f}   {m['r2_service']:.4f}")
print(f"  overall  : {m['mae_overall']:.4f}   {m['rmse_overall']:.4f}   {m['r2_overall']:.4f}")
print()
print(f"  mean_mae   : {m['mean_mae']:.4f}")
print(f"  aspect_mae : {m['aspect_mae']:.4f}")
print(f"  overall_mae: {m['overall_mae']:.4f}")
# Out:
# === EXP_041A_bestimage_besttext_film_mse Results ===
# Loss (val)   : 2.2243
#
#              MAE      RMSE      R2
#   food     : 1.1238   1.5133   0.5649
#   price    : 1.1783   1.5741   0.4452
#   atmos    : 1.1789   1.5302   0.3966
#   service  : 1.1890   1.5787   0.5139
#   overall  : 0.9278   1.2415   0.6215
#
#   mean_mae   : 1.1195
#   aspect_mae : 1.1675
#   overall_mae: 0.9278
