# %% [markdown]
# # EXP_041B — Fusion Ablation: Cross-Attention + MSE
# **Phase 4 | Fusion Upgrade**
# Research question: Does Cross-Attention improve fine-grained multimodal interaction?
# - Fusion: `cross_attention` | Loss: MSE | Seed: 42 | AMP: enabled
# > ⚠️ Set BEST_IMAGE_EXP_ID and BEST_TEXT_EXP_ID in STEP 4.

# %% [markdown]
# ### STEP 1: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### STEP 2: Clone source code and install dependencies

# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 13374, done.
# remote: Counting objects: 100% (245/245), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 13374 (delta 181), reused 163 (delta 102), pack-reused 13129 (from 1)
# Receiving objects: 100% (13374/13374), 873.22 MiB | 19.70 MiB/s, done.
# Resolving deltas: 100% (419/419), done.
# /content/SE365

# %% [markdown]
# ### STEP 3: Download and extract data

# %%
# !rm -rf ./data
# !cp /content/drive/MyDrive/SE365/data.zip ./data.zip
# !unzip -q data.zip
# !rm data.zip
# !ls -la ./data
# Out:
# total 1340
# drwxr-xr-x  4 root root    4096 Jun 16 09:21 .
# drwxr-xr-x 11 root root    4096 Jun 23 15:05 ..
# drwxr-xr-x  2 root root 1359872 Jun 16 09:59 image
# drwxr-xr-x  2 root root    4096 Jun 16 09:21 text

# %% [markdown]
# ### STEP 4: Configure paths — ✏️ Set Phase 2 & Phase 3 winners here

# %%
import os
DRIVE_ROOT = '/content/drive/MyDrive/SE365'  # ✏️ Change if needed
EXP_ID = 'EXP_041B_bestimage_besttext_crossattention_mse'

BEST_IMAGE_EXP_ID = 'EXP_020B_swinb_xlmr_concat_mse'  # ✏️ Phase 2 winner
BEST_IMAGE_MODEL  = 'swin_base_patch4_window7_224'
BEST_TEXT_EXP_ID  = 'EXP_030B_bestimage_phobert_concat_mse'  # ✏️ Phase 3 winner
BEST_TEXT_MODEL   = 'vinai/phobert-base-v2'

DRIVE_EXP_PATH = f'{DRIVE_ROOT}/experiments/{EXP_ID}'
os.makedirs(DRIVE_EXP_PATH, exist_ok=True)
print(f'Artifacts: {DRIVE_EXP_PATH}')
print(f'Image: {BEST_IMAGE_MODEL} | Text: {BEST_TEXT_MODEL}')
# Out:
# Artifacts: /content/drive/MyDrive/SE365/experiments/EXP_041B_bestimage_besttext_crossattention_mse
# Image: swin_base_patch4_window7_224 | Text: vinai/phobert-base-v2

# %% [markdown]
# ### STEP 5: Load pretrained weights

# %%
import os, shutil
os.makedirs('./checkpoints', exist_ok=True)
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_TEXT_EXP_ID}/best_model_train_text.pth', './checkpoints/best_model_train_text.pth')
print(f'Loaded text from {BEST_TEXT_EXP_ID}')
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_IMAGE_EXP_ID}/best_model_train_image.pth', './checkpoints/best_model_train_image.pth')
print(f'Loaded image from {BEST_IMAGE_EXP_ID}')
# Out:
# Loaded text from EXP_030B_bestimage_phobert_concat_mse
# Loaded image from EXP_020B_swinb_xlmr_concat_mse

# %% [markdown]
# ### STEP 6: Train

# %%
# !python main.py \
  --mode train_fusion \
  --fusion_type cross_attention \
  --text_model_name {BEST_TEXT_MODEL} \
  --image_model_name {BEST_IMAGE_MODEL} \
  --epochs 15 \
  --batch_size 16 \
  --lr 1e-5 \
  --grad_accum_steps 2 \
  --patience 5 \
  --loss_fn mse \
  --unfreeze_text_layers 1 \
  --unfreeze_image_layers 1 \
  --seed 42 \
  --use_amp \
  --exp_id EXP_041B_bestimage_besttext_crossattention_mse \
  --exp_dir ./experiments
# Out:
# ====== MODE: TRAIN_FUSION ======
# Using device: cuda
# Seed: 42 | Experiment: EXP_041B_bestimage_besttext_crossattention_mse
# config.json: 100% 678/678 [00:00<00:00, 3.77MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 100% 895k/895k [00:00<00:00, 86.4MB/s]
# bpe.codes: 100% 1.14M/1.14M [00:00<00:00, 119MB/s]
# tokenizer.json: 100% 3.13M/3.13M [00:00<00:00, 154MB/s]
# Loaded timm processor for swin_base_patch4_window7_224
# pytorch_model.bin: 100% 540M/540M [00:04<00:00, 121MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 33858.30it/s]
# [transformers] RobertaModel LOAD REPORT from: vinai/phobert-base-v2
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.layer_norm.weight | UNEXPECTED |
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.layer_norm.bias   | UNEXPECTED |
# lm_head.bias              | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# pooler.dense.bias         | MISSING    |
# pooler.dense.weight       | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:  62% 336M/540M [00:02<00:00, 850MB/s]
# model.safetensors:  30% 106M/353M [00:02<00:01, 145MB/s]
# model.safetensors:  42% 149M/353M [00:02<00:01, 191MB/s]
# model.safetensors: 100% 540M/540M [00:03<00:00, 494MB/s]
# model.safetensors:  85% 298M/353M [00:03<00:00, 283MB/s]
# model.safetensors: 100% 540M/540M [00:03<00:00, 146MB/s]
# model.safetensors: 100% 353M/353M [00:03<00:00, 99.9MB/s]
# /content/SE365/Trainer.py:82: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.use_amp)
# 2026-06-23 15:06:25 ====== START: 2026-06-23T15:06:25.715332 ======
# 2026-06-23 15:06:25 Experiment: EXP_041B_bestimage_besttext_crossattention_mse | Mode: train_fusion | exp_dir: ./experiments/EXP_041B_bestimage_besttext_crossattention_mse
# Epoch 1/15:   0% 0/300 [00:00<?, ?it/s]/content/SE365/Trainer.py:121: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# Epoch 1/15:   0% 1/300 [00:02<12:48,  2.57s/it, loss=55.3, lr=0]/content/SE365/Trainer.py:132: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   self.scheduler.step()
# Epoch 1/15: 100% 300/300 [04:32<00:00,  1.10it/s, loss=47.8, lr=6.67e-6]
# /content/SE365/Trainer.py:151: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# 2026-06-23 15:11:28 Epoch 1/15 | Train Loss: 54.4188 | Val Loss: 46.1557 | Mean MAE: 6.4472
# 2026-06-23 15:11:28   -> MAE  | Food: 6.9203 | Price: 6.3945 | Atmos: 6.1747 | Service: 6.3516 | Overall: 6.3951
# 2026-06-23 15:11:28   -> RMSE | Food: 7.2845 | Price: 6.7266 | Atmos: 6.4737 | Service: 6.7348 | Overall: 6.6918
# 2026-06-23 15:11:28   -> R2   | Food: -9.0821 | Price: -9.1306 | Atmos: -9.7984 | Service: -7.8465 | Overall: -9.9976
# 2026-06-23 15:11:30 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=6.4472) ***
# Epoch 2/15: 100% 300/300 [04:06<00:00,  1.22it/s, loss=2.25, lr=9.97e-6]
# 2026-06-23 15:16:17 Epoch 2/15 | Train Loss: 17.0396 | Val Loss: 2.1913 | Mean MAE: 1.1402
# 2026-06-23 15:16:17   -> MAE  | Food: 1.1453 | Price: 1.1860 | Atmos: 1.1991 | Service: 1.2242 | Overall: 0.9463
# 2026-06-23 15:16:17   -> RMSE | Food: 1.4871 | Price: 1.5685 | Atmos: 1.5344 | Service: 1.5745 | Overall: 1.2146
# 2026-06-23 15:16:17   -> R2   | Food: 0.5798 | Price: 0.4492 | Atmos: 0.3934 | Service: 0.5165 | Overall: 0.6377
# 2026-06-23 15:16:24 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=1.1402) ***
# Epoch 3/15: 100% 300/300 [04:20<00:00,  1.15it/s, loss=1.86, lr=9.7e-6]
# 2026-06-23 15:21:14 Epoch 3/15 | Train Loss: 2.0685 | Val Loss: 2.2765 | Mean MAE: 1.1337
# 2026-06-23 15:21:14   -> MAE  | Food: 1.1504 | Price: 1.1705 | Atmos: 1.1934 | Service: 1.2072 | Overall: 0.9472
# 2026-06-23 15:21:14   -> RMSE | Food: 1.5585 | Price: 1.5611 | Atmos: 1.5442 | Service: 1.6008 | Overall: 1.2606
# 2026-06-23 15:21:14   -> R2   | Food: 0.5385 | Price: 0.4544 | Atmos: 0.3856 | Service: 0.5002 | Overall: 0.6097
# 2026-06-23 15:21:17 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=1.1337) ***
# Epoch 4/15: 100% 300/300 [04:17<00:00,  1.17it/s, loss=1.46, lr=9.18e-6]
# 2026-06-23 15:26:03 Epoch 4/15 | Train Loss: 1.9622 | Val Loss: 2.2071 | Mean MAE: 1.1260
# 2026-06-23 15:26:03   -> MAE  | Food: 1.1264 | Price: 1.1741 | Atmos: 1.1859 | Service: 1.1936 | Overall: 0.9498
# 2026-06-23 15:26:03   -> RMSE | Food: 1.5038 | Price: 1.5659 | Atmos: 1.5237 | Service: 1.5704 | Overall: 1.2469
# 2026-06-23 15:26:03   -> R2   | Food: 0.5703 | Price: 0.4510 | Atmos: 0.4018 | Service: 0.5190 | Overall: 0.6181
# 2026-06-23 15:26:10 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=1.1260) ***
# Epoch 5/15: 100% 300/300 [04:13<00:00,  1.18it/s, loss=1.55, lr=8.43e-6]
# 2026-06-23 15:30:58 Epoch 5/15 | Train Loss: 1.9401 | Val Loss: 2.2149 | Mean MAE: 1.1214
# 2026-06-23 15:30:58   -> MAE  | Food: 1.1215 | Price: 1.1831 | Atmos: 1.1807 | Service: 1.1890 | Overall: 0.9329
# 2026-06-23 15:30:58   -> RMSE | Food: 1.5112 | Price: 1.5783 | Atmos: 1.5225 | Service: 1.5705 | Overall: 1.2377
# 2026-06-23 15:30:58   -> R2   | Food: 0.5661 | Price: 0.4423 | Atmos: 0.4027 | Service: 0.5189 | Overall: 0.6238
# 2026-06-23 15:31:05 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=1.1214) ***
# Epoch 6/15: 100% 300/300 [04:08<00:00,  1.21it/s, loss=2.79, lr=7.5e-6]
# 2026-06-23 15:35:44 Epoch 6/15 | Train Loss: 1.9264 | Val Loss: 2.1858 | Mean MAE: 1.1153
# 2026-06-23 15:35:44   -> MAE  | Food: 1.1120 | Price: 1.1736 | Atmos: 1.1779 | Service: 1.1872 | Overall: 0.9260
# 2026-06-23 15:35:44   -> RMSE | Food: 1.4925 | Price: 1.5662 | Atmos: 1.5177 | Service: 1.5678 | Overall: 1.2271
# 2026-06-23 15:35:44   -> R2   | Food: 0.5767 | Price: 0.4508 | Atmos: 0.4065 | Service: 0.5206 | Overall: 0.6302
# 2026-06-23 15:35:46 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=1.1153) ***
# Epoch 7/15: 100% 300/300 [04:32<00:00,  1.10it/s, loss=1.39, lr=6.43e-6]
# 2026-06-23 15:40:51 Epoch 7/15 | Train Loss: 1.8742 | Val Loss: 2.2934 | Mean MAE: 1.1399
# 2026-06-23 15:40:51   -> MAE  | Food: 1.1352 | Price: 1.2023 | Atmos: 1.1964 | Service: 1.2122 | Overall: 0.9533
# 2026-06-23 15:40:51   -> RMSE | Food: 1.5267 | Price: 1.6049 | Atmos: 1.5489 | Service: 1.6080 | Overall: 1.2636
# 2026-06-23 15:40:52   -> R2   | Food: 0.5571 | Price: 0.4233 | Atmos: 0.3818 | Service: 0.4957 | Overall: 0.6079
# 2026-06-23 15:40:52 No improvement for 1/5 epoch(s).
# Epoch 8/15: 100% 300/300 [04:31<00:00,  1.10it/s, loss=1.52, lr=5.29e-6]
# 2026-06-23 15:45:58 Epoch 8/15 | Train Loss: 1.8815 | Val Loss: 2.1888 | Mean MAE: 1.1111
# 2026-06-23 15:45:58   -> MAE  | Food: 1.1137 | Price: 1.1726 | Atmos: 1.1732 | Service: 1.1782 | Overall: 0.9178
# 2026-06-23 15:45:58   -> RMSE | Food: 1.5046 | Price: 1.5643 | Atmos: 1.5156 | Service: 1.5644 | Overall: 1.2273
# 2026-06-23 15:45:58   -> R2   | Food: 0.5699 | Price: 0.4521 | Atmos: 0.4081 | Service: 0.5227 | Overall: 0.6301
# 2026-06-23 15:46:01 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=1.1111) ***
# Epoch 9/15: 100% 300/300 [04:09<00:00,  1.20it/s, loss=1.89, lr=4.13e-6]
# 2026-06-23 15:50:40 Epoch 9/15 | Train Loss: 1.8516 | Val Loss: 2.1920 | Mean MAE: 1.1113
# 2026-06-23 15:50:40   -> MAE  | Food: 1.1138 | Price: 1.1720 | Atmos: 1.1730 | Service: 1.1819 | Overall: 0.9161
# 2026-06-23 15:50:40   -> RMSE | Food: 1.5035 | Price: 1.5665 | Atmos: 1.5167 | Service: 1.5710 | Overall: 1.2235
# 2026-06-23 15:50:40   -> R2   | Food: 0.5705 | Price: 0.4506 | Atmos: 0.4073 | Service: 0.5186 | Overall: 0.6323
# 2026-06-23 15:50:40 No improvement for 1/5 epoch(s).
# Epoch 10/15: 100% 300/300 [04:23<00:00,  1.14it/s, loss=1.6, lr=3.02e-6]
# 2026-06-23 15:55:34 Epoch 10/15 | Train Loss: 1.8789 | Val Loss: 2.1750 | Mean MAE: 1.1079
# 2026-06-23 15:55:34   -> MAE  | Food: 1.1024 | Price: 1.1728 | Atmos: 1.1743 | Service: 1.1756 | Overall: 0.9143
# 2026-06-23 15:55:34   -> RMSE | Food: 1.4887 | Price: 1.5633 | Atmos: 1.5172 | Service: 1.5613 | Overall: 1.2215
# 2026-06-23 15:55:34   -> R2   | Food: 0.5789 | Price: 0.4528 | Atmos: 0.4069 | Service: 0.5246 | Overall: 0.6335
# 2026-06-23 15:55:36 *** Saved best model to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth (mean_mae=1.1079) ***
# Epoch 11/15: 100% 300/300 [04:17<00:00,  1.17it/s, loss=1.06, lr=2.01e-6]
# 2026-06-23 16:00:24 Epoch 11/15 | Train Loss: 1.8503 | Val Loss: 2.1856 | Mean MAE: 1.1107
# 2026-06-23 16:00:24   -> MAE  | Food: 1.1139 | Price: 1.1728 | Atmos: 1.1742 | Service: 1.1751 | Overall: 0.9175
# 2026-06-23 16:00:24   -> RMSE | Food: 1.5020 | Price: 1.5656 | Atmos: 1.5176 | Service: 1.5607 | Overall: 1.2248
# 2026-06-23 16:00:24   -> R2   | Food: 0.5714 | Price: 0.4512 | Atmos: 0.4066 | Service: 0.5249 | Overall: 0.6316
# 2026-06-23 16:00:24 No improvement for 1/5 epoch(s).
# Epoch 12/15: 100% 300/300 [04:31<00:00,  1.11it/s, loss=3.28, lr=1.17e-6]
# 2026-06-23 16:05:25 Epoch 12/15 | Train Loss: 1.8348 | Val Loss: 2.1830 | Mean MAE: 1.1094
# 2026-06-23 16:05:25   -> MAE  | Food: 1.1070 | Price: 1.1749 | Atmos: 1.1738 | Service: 1.1739 | Overall: 0.9172
# 2026-06-23 16:05:25   -> RMSE | Food: 1.4944 | Price: 1.5691 | Atmos: 1.5171 | Service: 1.5603 | Overall: 1.2252
# 2026-06-23 16:05:25   -> R2   | Food: 0.5757 | Price: 0.4488 | Atmos: 0.4070 | Service: 0.5252 | Overall: 0.6313
# 2026-06-23 16:05:25 No improvement for 2/5 epoch(s).
# Epoch 13/15: 100% 300/300 [04:08<00:00,  1.21it/s, loss=2.25, lr=5.32e-7]
# 2026-06-23 16:10:04 Epoch 13/15 | Train Loss: 1.8873 | Val Loss: 2.1948 | Mean MAE: 1.1131
# 2026-06-23 16:10:04   -> MAE  | Food: 1.1171 | Price: 1.1751 | Atmos: 1.1749 | Service: 1.1783 | Overall: 0.9202
# 2026-06-23 16:10:04   -> RMSE | Food: 1.5051 | Price: 1.5700 | Atmos: 1.5186 | Service: 1.5653 | Overall: 1.2275
# 2026-06-23 16:10:04   -> R2   | Food: 0.5696 | Price: 0.4481 | Atmos: 0.4058 | Service: 0.5221 | Overall: 0.6299
# 2026-06-23 16:10:04 No improvement for 3/5 epoch(s).
# Epoch 14/15: 100% 300/300 [04:19<00:00,  1.16it/s, loss=1.86, lr=1.35e-7]
# 2026-06-23 16:14:53 Epoch 14/15 | Train Loss: 1.8512 | Val Loss: 2.1882 | Mean MAE: 1.1111
# 2026-06-23 16:14:53   -> MAE  | Food: 1.1131 | Price: 1.1742 | Atmos: 1.1743 | Service: 1.1761 | Overall: 0.9178
# 2026-06-23 16:14:53   -> RMSE | Food: 1.5011 | Price: 1.5677 | Atmos: 1.5179 | Service: 1.5627 | Overall: 1.2257
# 2026-06-23 16:14:53   -> R2   | Food: 0.5718 | Price: 0.4497 | Atmos: 0.4063 | Service: 0.5237 | Overall: 0.6310
# 2026-06-23 16:14:53 No improvement for 4/5 epoch(s).
# Epoch 15/15: 100% 300/300 [04:02<00:00,  1.24it/s, loss=1.62, lr=0]
# 2026-06-23 16:19:26 Epoch 15/15 | Train Loss: 1.8872 | Val Loss: 2.1914 | Mean MAE: 1.1120
# 2026-06-23 16:19:26   -> MAE  | Food: 1.1151 | Price: 1.1746 | Atmos: 1.1745 | Service: 1.1769 | Overall: 0.9188
# 2026-06-23 16:19:26   -> RMSE | Food: 1.5034 | Price: 1.5685 | Atmos: 1.5182 | Service: 1.5637 | Overall: 1.2270
# 2026-06-23 16:19:26   -> R2   | Food: 0.5706 | Price: 0.4492 | Atmos: 0.4061 | Service: 0.5231 | Overall: 0.6302
# 2026-06-23 16:19:26 No improvement for 5/5 epoch(s).
# 2026-06-23 16:19:26 Early stopping triggered after 15 epochs!
# 2026-06-23 16:19:26 ====== Final evaluation with best checkpoint ======
# 2026-06-23 16:19:27 Loaded best checkpoint from ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/best_model_train_fusion.pth
# 2026-06-23 16:19:57 Final Val Loss: 2.1750 | Mean MAE: 1.1079
# 2026-06-23 16:19:57 Metrics saved to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/metrics.json
# 2026-06-23 16:19:57 Predictions saved to ./experiments/EXP_041B_bestimage_besttext_crossattention_mse/predictions.csv
# 2026-06-23 16:19:57 ====== END: 2026-06-23T16:19:57.585165 ======

# %% [markdown]
# ### STEP 7: Save to Drive + print metrics

# %%
import json
# !cp -r ./experiments/$EXP_ID/* $DRIVE_EXP_PATH/

with open(f'./experiments/{EXP_ID}/metrics.json') as f:
    m = json.load(f)

print(f'\n=== {EXP_ID} Results ===')
print(f"Loss (val)   : {m['loss']:.4f}")
print()
print("             MAE      RMSE      R2")
print(f"  food     : {m['mae_food']:.4f}   {m['rmse_food']:.4f}   {m['r2_food']:.4f}")
print(f"  price    : {m['mae_price']:.4f}   {m['rmse_price']:.4f}   {m['r2_price']:.4f}")
print(f"  atmos    : {m['mae_atmos']:.4f}   {m['rmse_atmos']:.4f}   {m['r2_atmos']:.4f}")
print(f"  service  : {m['mae_service']:.4f}   {m['rmse_service']:.4f}   {m['r2_service']:.4f}")
print(f"  overall  : {m['mae_overall']:.4f}   {m['rmse_overall']:.4f}   {m['r2_overall']:.4f}")
print()
print(f"  mean_mae   : {m['mean_mae']:.4f}")
print(f"  aspect_mae : {m['aspect_mae']:.4f}")
print(f"  overall_mae: {m['overall_mae']:.4f}")
# Out:
# === EXP_041B_bestimage_besttext_crossattention_mse Results ===
# Loss (val)   : 2.1750
#
#              MAE      RMSE      R2
#   food     : 1.1024   1.4887   0.5789
#   price    : 1.1728   1.5633   0.4528
#   atmos    : 1.1743   1.5172   0.4069
#   service  : 1.1756   1.5613   0.5246
#   overall  : 0.9143   1.2215   0.6335
#
#   mean_mae   : 1.1079
#   aspect_mae : 1.1563
#   overall_mae: 0.9143
