# %% [markdown]
# # EXP_051D — Task Balancing: Homoscedastic Uncertainty Weighted
# **Phase 5 | Loss Ablation**
# Research question: Does learnable task uncertainty weighting improve 5-target balance?
# - Loss: `auto_weight` (HomoscedasticUncertaintyLoss) | Seed: 42 | AMP: enabled
# > ⚠️ Set BEST_FUSION_TYPE, BEST_IMAGE_MODEL, BEST_TEXT_MODEL in STEP 4.

# %% [markdown]
# ### STEP 1: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### STEP 2: Clone source code and install dependencies

# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 13390, done.
# remote: Counting objects: 100% (261/261), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 13390 (delta 191), reused 171 (delta 104), pack-reused 13129 (from 1)
# Receiving objects: 100% (13390/13390), 873.22 MiB | 10.66 MiB/s, done.
# Resolving deltas: 100% (429/429), done.
# /content/SE365

# %% [markdown]
# ### STEP 3: Download and extract data

# %%
# !rm -rf ./data
# !cp /content/drive/MyDrive/SE365/data.zip ./data.zip
# !unzip -q data.zip
# !rm data.zip
# !ls -la ./data
# Out:
# total 1416
# drwxr-xr-x  4 root root    4096 Jun 16 09:21 .
# drwxr-xr-x 11 root root    4096 Jun 23 17:39 ..
# drwxr-xr-x  2 root root 1437696 Jun 16 09:59 image
# drwxr-xr-x  2 root root    4096 Jun 16 09:21 text

# %% [markdown]
# ### STEP 4: Configure paths — ✏️ Set Phase 2, 3, 4 winners here

# %%
import os
DRIVE_ROOT = '/content/drive/MyDrive/SE365'  # ✏️ Change if needed
EXP_ID = 'EXP_051D_bestfusion_uncertaintyweighted'

BEST_IMAGE_MODEL  = 'swin_base_patch4_window7_224'   # ✏️ Phase 2 winner
BEST_TEXT_MODEL   = 'vinai/phobert-base-v2'           # ✏️ Phase 3 winner
BEST_FUSION_TYPE  = 'cross_attention'                             # ✏️ Phase 4 winner (concat/gmu/gated_cross/film/cross_attention)
BEST_IMAGE_EXP_ID = 'EXP_020B_swinb_xlmr_concat_mse'
BEST_TEXT_EXP_ID  = 'EXP_030B_bestimage_phobert_concat_mse'

DRIVE_EXP_PATH = f'{DRIVE_ROOT}/experiments/{EXP_ID}'
os.makedirs(DRIVE_EXP_PATH, exist_ok=True)
print(f'Artifacts: {DRIVE_EXP_PATH}')
print(f'Fusion: {BEST_FUSION_TYPE} | Image: {BEST_IMAGE_MODEL} | Text: {BEST_TEXT_MODEL}')
# Out:
# Artifacts: /content/drive/MyDrive/SE365/experiments/EXP_051D_bestfusion_uncertaintyweighted
# Fusion: cross_attention | Image: swin_base_patch4_window7_224 | Text: vinai/phobert-base-v2

# %% [markdown]
# ### STEP 5: Load pretrained weights

# %%
import os, shutil
os.makedirs('./checkpoints', exist_ok=True)
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_TEXT_EXP_ID}/best_model_train_text.pth', './checkpoints/best_model_train_text.pth')
print(f'Loaded text from {BEST_TEXT_EXP_ID}')
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_IMAGE_EXP_ID}/best_model_train_image.pth', './checkpoints/best_model_train_image.pth')
print(f'Loaded image from {BEST_IMAGE_EXP_ID}')
# Out:
# Loaded text from EXP_030B_bestimage_phobert_concat_mse
# Loaded image from EXP_020B_swinb_xlmr_concat_mse

# %% [markdown]
# ### STEP 6: Train

# %%
# !python main.py \
  --mode train_fusion \
  --fusion_type {BEST_FUSION_TYPE} \
  --text_model_name {BEST_TEXT_MODEL} \
  --image_model_name {BEST_IMAGE_MODEL} \
  --epochs 15 \
  --batch_size 16 \
  --lr 1e-5 \
  --grad_accum_steps 2 \
  --patience 5 \
  --loss_fn auto_weight \
  --unfreeze_text_layers 1 \
  --unfreeze_image_layers 1 \
  --seed 42 \
  --use_amp \
  --exp_id EXP_051D_bestfusion_uncertaintyweighted \
  --exp_dir ./experiments
# Out:
# ====== MODE: TRAIN_FUSION ======
# Using device: cuda
# Seed: 42 | Experiment: EXP_051D_bestfusion_uncertaintyweighted
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 678/678 [00:00<00:00, 3.04MB/s]
# vocab.txt: 100% 895k/895k [00:00<00:00, 100MB/s]
# bpe.codes: 100% 1.14M/1.14M [00:00<00:00, 117MB/s]
# tokenizer.json: 100% 3.13M/3.13M [00:00<00:00, 151MB/s]
# Loaded timm processor for swin_base_patch4_window7_224
# pytorch_model.bin: 100% 540M/540M [00:03<00:00, 150MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 18300.32it/s]
# [transformers] RobertaModel LOAD REPORT from: vinai/phobert-base-v2
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.dense.bias        | UNEXPECTED |
# lm_head.bias              | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.layer_norm.bias   | UNEXPECTED |
# pooler.dense.weight       | MISSING    |
# pooler.dense.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:02<?, ?B/s]
# model.safetensors:   0% 131k/540M [00:02<06:54, 1.30MB/s]
# model.safetensors:  37% 201M/540M [00:02<00:00, 743MB/s]
# model.safetensors:  40% 142M/353M [00:02<00:00, 287MB/s]
# model.safetensors:  54% 191M/353M [00:02<00:00, 341MB/s]
# model.safetensors:  75% 265M/353M [00:02<00:00, 452MB/s]
# model.safetensors: 100% 353M/353M [00:03<00:00, 105MB/s]
# model.safetensors: 100% 540M/540M [00:03<00:00, 148MB/s]
# /content/SE365/Trainer.py:82: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.use_amp)
# 2026-06-23 17:41:10 ====== START: 2026-06-23T17:41:10.075572 ======
# 2026-06-23 17:41:10 Experiment: EXP_051D_bestfusion_uncertaintyweighted | Mode: train_fusion | exp_dir: ./experiments/EXP_051D_bestfusion_uncertaintyweighted
# Epoch 1/15:   0% 0/300 [00:00<?, ?it/s]/content/SE365/Trainer.py:121: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# Epoch 1/15:   0% 1/300 [00:02<12:19,  2.47s/it, loss=55.3, lr=0]/content/SE365/Trainer.py:132: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   self.scheduler.step()
# Epoch 1/15: 100% 300/300 [04:10<00:00,  1.20it/s, loss=47.8, lr=6.67e-6]
# /content/SE365/Trainer.py:151: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# 2026-06-23 17:45:51 Epoch 1/15 | Train Loss: 54.4109 | Val Loss: 46.1347 | Mean MAE: 6.4472
# 2026-06-23 17:45:51   -> MAE  | Food: 6.9204 | Price: 6.3946 | Atmos: 6.1746 | Service: 6.3517 | Overall: 6.3950
# 2026-06-23 17:45:51   -> RMSE | Food: 7.2845 | Price: 6.7267 | Atmos: 6.4735 | Service: 6.7349 | Overall: 6.6917
# 2026-06-23 17:45:51   -> R2   | Food: -9.0823 | Price: -9.1306 | Atmos: -9.7979 | Service: -7.8467 | Overall: -9.9973
# 2026-06-23 17:45:53 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=6.4472) ***
# Epoch 2/15: 100% 300/300 [04:17<00:00,  1.17it/s, loss=2.25, lr=9.97e-6]
# 2026-06-23 17:50:41 Epoch 2/15 | Train Loss: 17.0292 | Val Loss: 2.1896 | Mean MAE: 1.1399
# 2026-06-23 17:50:41   -> MAE  | Food: 1.1451 | Price: 1.1859 | Atmos: 1.1990 | Service: 1.2232 | Overall: 0.9465
# 2026-06-23 17:50:41   -> RMSE | Food: 1.4870 | Price: 1.5684 | Atmos: 1.5343 | Service: 1.5737 | Overall: 1.2148
# 2026-06-23 17:50:41   -> R2   | Food: 0.5799 | Price: 0.4492 | Atmos: 0.3934 | Service: 0.5170 | Overall: 0.6376
# 2026-06-23 17:50:47 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=1.1399) ***
# Epoch 3/15: 100% 300/300 [04:20<00:00,  1.15it/s, loss=1.86, lr=9.7e-6]
# 2026-06-23 17:55:48 Epoch 3/15 | Train Loss: 2.0676 | Val Loss: 2.2740 | Mean MAE: 1.1335
# 2026-06-23 17:55:48   -> MAE  | Food: 1.1507 | Price: 1.1702 | Atmos: 1.1924 | Service: 1.2078 | Overall: 0.9465
# 2026-06-23 17:55:48   -> RMSE | Food: 1.5584 | Price: 1.5608 | Atmos: 1.5429 | Service: 1.6013 | Overall: 1.2597
# 2026-06-23 17:55:48   -> R2   | Food: 0.5386 | Price: 0.4546 | Atmos: 0.3866 | Service: 0.4999 | Overall: 0.6103
# 2026-06-23 17:55:52 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=1.1335) ***
# Epoch 4/15: 100% 300/300 [04:10<00:00,  1.20it/s, loss=1.46, lr=9.18e-6]
# 2026-06-23 18:00:47 Epoch 4/15 | Train Loss: 1.9616 | Val Loss: 2.2053 | Mean MAE: 1.1258
# 2026-06-23 18:00:47   -> MAE  | Food: 1.1257 | Price: 1.1746 | Atmos: 1.1854 | Service: 1.1931 | Overall: 0.9500
# 2026-06-23 18:00:47   -> RMSE | Food: 1.5031 | Price: 1.5668 | Atmos: 1.5230 | Service: 1.5700 | Overall: 1.2469
# 2026-06-23 18:00:47   -> R2   | Food: 0.5707 | Price: 0.4503 | Atmos: 0.4024 | Service: 0.5192 | Overall: 0.6182
# 2026-06-23 18:00:50 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=1.1258) ***
# Epoch 5/15: 100% 300/300 [04:06<00:00,  1.22it/s, loss=1.55, lr=8.43e-6]
# 2026-06-23 18:05:26 Epoch 5/15 | Train Loss: 1.9397 | Val Loss: 2.2135 | Mean MAE: 1.1214
# 2026-06-23 18:05:26   -> MAE  | Food: 1.1220 | Price: 1.1831 | Atmos: 1.1802 | Service: 1.1894 | Overall: 0.9323
# 2026-06-23 18:05:26   -> RMSE | Food: 1.5118 | Price: 1.5783 | Atmos: 1.5218 | Service: 1.5713 | Overall: 1.2366
# 2026-06-23 18:05:26   -> R2   | Food: 0.5657 | Price: 0.4423 | Atmos: 0.4033 | Service: 0.5184 | Overall: 0.6245
# 2026-06-23 18:05:29 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=1.1214) ***
# Epoch 6/15: 100% 300/300 [04:24<00:00,  1.14it/s, loss=2.78, lr=7.5e-6]
# 2026-06-23 18:10:23 Epoch 6/15 | Train Loss: 1.9259 | Val Loss: 2.1837 | Mean MAE: 1.1151
# 2026-06-23 18:10:23   -> MAE  | Food: 1.1123 | Price: 1.1730 | Atmos: 1.1776 | Service: 1.1875 | Overall: 0.9249
# 2026-06-23 18:10:23   -> RMSE | Food: 1.4928 | Price: 1.5655 | Atmos: 1.5174 | Service: 1.5687 | Overall: 1.2258
# 2026-06-23 18:10:23   -> R2   | Food: 0.5766 | Price: 0.4513 | Atmos: 0.4067 | Service: 0.5201 | Overall: 0.6310
# 2026-06-23 18:10:26 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=1.1151) ***
# Epoch 7/15: 100% 300/300 [04:19<00:00,  1.16it/s, loss=1.4, lr=6.43e-6]
# 2026-06-23 18:15:20 Epoch 7/15 | Train Loss: 1.8733 | Val Loss: 2.2918 | Mean MAE: 1.1396
# 2026-06-23 18:15:20   -> MAE  | Food: 1.1362 | Price: 1.2015 | Atmos: 1.1955 | Service: 1.2136 | Overall: 0.9513
# 2026-06-23 18:15:20   -> RMSE | Food: 1.5281 | Price: 1.6041 | Atmos: 1.5480 | Service: 1.6102 | Overall: 1.2612
# 2026-06-23 18:15:20   -> R2   | Food: 0.5563 | Price: 0.4239 | Atmos: 0.3826 | Service: 0.4943 | Overall: 0.6093
# 2026-06-23 18:15:20 No improvement for 1/5 epoch(s).
# Epoch 8/15: 100% 300/300 [04:30<00:00,  1.11it/s, loss=1.51, lr=5.29e-6]
# 2026-06-23 18:20:21 Epoch 8/15 | Train Loss: 1.8801 | Val Loss: 2.1878 | Mean MAE: 1.1112
# 2026-06-23 18:20:21   -> MAE  | Food: 1.1141 | Price: 1.1724 | Atmos: 1.1732 | Service: 1.1787 | Overall: 0.9175
# 2026-06-23 18:20:21   -> RMSE | Food: 1.5055 | Price: 1.5641 | Atmos: 1.5157 | Service: 1.5651 | Overall: 1.2266
# 2026-06-23 18:20:21   -> R2   | Food: 0.5694 | Price: 0.4523 | Atmos: 0.4080 | Service: 0.5222 | Overall: 0.6305
# 2026-06-23 18:20:24 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=1.1112) ***
# Epoch 9/15: 100% 300/300 [04:37<00:00,  1.08it/s, loss=1.9, lr=4.13e-6]
# 2026-06-23 18:25:37 Epoch 9/15 | Train Loss: 1.8514 | Val Loss: 2.1903 | Mean MAE: 1.1113
# 2026-06-23 18:25:37   -> MAE  | Food: 1.1133 | Price: 1.1719 | Atmos: 1.1728 | Service: 1.1828 | Overall: 0.9158
# 2026-06-23 18:25:37   -> RMSE | Food: 1.5029 | Price: 1.5662 | Atmos: 1.5168 | Service: 1.5721 | Overall: 1.2229
# 2026-06-23 18:25:37   -> R2   | Food: 0.5708 | Price: 0.4508 | Atmos: 0.4072 | Service: 0.5179 | Overall: 0.6327
# 2026-06-23 18:25:37 No improvement for 1/5 epoch(s).
# Epoch 10/15: 100% 300/300 [04:19<00:00,  1.16it/s, loss=1.61, lr=3.02e-6]
# 2026-06-23 18:30:31 Epoch 10/15 | Train Loss: 1.8790 | Val Loss: 2.1738 | Mean MAE: 1.1080
# 2026-06-23 18:30:31   -> MAE  | Food: 1.1024 | Price: 1.1727 | Atmos: 1.1742 | Service: 1.1764 | Overall: 0.9144
# 2026-06-23 18:30:31   -> RMSE | Food: 1.4885 | Price: 1.5632 | Atmos: 1.5175 | Service: 1.5623 | Overall: 1.2213
# 2026-06-23 18:30:31   -> R2   | Food: 0.5790 | Price: 0.4529 | Atmos: 0.4067 | Service: 0.5240 | Overall: 0.6337
# 2026-06-23 18:30:34 *** Saved best model to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth (mean_mae=1.1080) ***
# Epoch 11/15: 100% 300/300 [04:29<00:00,  1.11it/s, loss=1.06, lr=2.01e-6]
# 2026-06-23 18:35:34 Epoch 11/15 | Train Loss: 1.8489 | Val Loss: 2.1840 | Mean MAE: 1.1107
# 2026-06-23 18:35:34   -> MAE  | Food: 1.1132 | Price: 1.1728 | Atmos: 1.1743 | Service: 1.1760 | Overall: 0.9173
# 2026-06-23 18:35:34   -> RMSE | Food: 1.5012 | Price: 1.5654 | Atmos: 1.5180 | Service: 1.5619 | Overall: 1.2242
# 2026-06-23 18:35:34   -> R2   | Food: 0.5718 | Price: 0.4514 | Atmos: 0.4063 | Service: 0.5242 | Overall: 0.6319
# 2026-06-23 18:35:34 No improvement for 1/5 epoch(s).
# Epoch 12/15: 100% 300/300 [04:43<00:00,  1.06it/s, loss=3.27, lr=1.17e-6]
# 2026-06-23 18:40:49 Epoch 12/15 | Train Loss: 1.8346 | Val Loss: 2.1812 | Mean MAE: 1.1094
# 2026-06-23 18:40:49   -> MAE  | Food: 1.1063 | Price: 1.1749 | Atmos: 1.1738 | Service: 1.1748 | Overall: 0.9170
# 2026-06-23 18:40:49   -> RMSE | Food: 1.4934 | Price: 1.5691 | Atmos: 1.5173 | Service: 1.5614 | Overall: 1.2248
# 2026-06-23 18:40:49   -> R2   | Food: 0.5763 | Price: 0.4488 | Atmos: 0.4068 | Service: 0.5245 | Overall: 0.6316
# 2026-06-23 18:40:49 No improvement for 2/5 epoch(s).
# Epoch 13/15: 100% 300/300 [04:53<00:00,  1.02it/s, loss=2.25, lr=5.32e-7]
# 2026-06-23 18:46:13 Epoch 13/15 | Train Loss: 1.8865 | Val Loss: 2.1929 | Mean MAE: 1.1130
# 2026-06-23 18:46:13   -> MAE  | Food: 1.1158 | Price: 1.1752 | Atmos: 1.1748 | Service: 1.1792 | Overall: 0.9200
# 2026-06-23 18:46:13   -> RMSE | Food: 1.5035 | Price: 1.5699 | Atmos: 1.5191 | Service: 1.5665 | Overall: 1.2273
# 2026-06-23 18:46:13   -> R2   | Food: 0.5705 | Price: 0.4482 | Atmos: 0.4054 | Service: 0.5214 | Overall: 0.6301
# 2026-06-23 18:46:13 No improvement for 3/5 epoch(s).
# Epoch 14/15: 100% 300/300 [04:20<00:00,  1.15it/s, loss=1.86, lr=1.35e-7]
# 2026-06-23 18:51:04 Epoch 14/15 | Train Loss: 1.8511 | Val Loss: 2.1865 | Mean MAE: 1.1110
# 2026-06-23 18:51:04   -> MAE  | Food: 1.1120 | Price: 1.1743 | Atmos: 1.1743 | Service: 1.1770 | Overall: 0.9176
# 2026-06-23 18:51:04   -> RMSE | Food: 1.4998 | Price: 1.5678 | Atmos: 1.5182 | Service: 1.5639 | Overall: 1.2254
# 2026-06-23 18:51:04   -> R2   | Food: 0.5726 | Price: 0.4497 | Atmos: 0.4061 | Service: 0.5230 | Overall: 0.6312
# 2026-06-23 18:51:04 No improvement for 4/5 epoch(s).
# Epoch 15/15: 100% 300/300 [04:27<00:00,  1.12it/s, loss=1.61, lr=0]
# 2026-06-23 18:56:08 Epoch 15/15 | Train Loss: 1.8869 | Val Loss: 2.1899 | Mean MAE: 1.1119
# 2026-06-23 18:56:08   -> MAE  | Food: 1.1139 | Price: 1.1747 | Atmos: 1.1745 | Service: 1.1779 | Overall: 0.9186
# 2026-06-23 18:56:08   -> RMSE | Food: 1.5021 | Price: 1.5685 | Atmos: 1.5186 | Service: 1.5651 | Overall: 1.2266
# 2026-06-23 18:56:08   -> R2   | Food: 0.5713 | Price: 0.4492 | Atmos: 0.4058 | Service: 0.5222 | Overall: 0.6305
# 2026-06-23 18:56:08 No improvement for 5/5 epoch(s).
# 2026-06-23 18:56:08 Early stopping triggered after 15 epochs!
# 2026-06-23 18:56:08 ====== Final evaluation with best checkpoint ======
# 2026-06-23 18:56:09 Loaded best checkpoint from ./experiments/EXP_051D_bestfusion_uncertaintyweighted/best_model_train_fusion.pth
# 2026-06-23 18:56:39 Final Val Loss: 2.1737 | Mean MAE: 1.1080
# 2026-06-23 18:56:39 Metrics saved to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/metrics.json
# 2026-06-23 18:56:39 Predictions saved to ./experiments/EXP_051D_bestfusion_uncertaintyweighted/predictions.csv
# 2026-06-23 18:56:39 ====== END: 2026-06-23T18:56:39.435267 ======

# %% [markdown]
# ### STEP 7: Save to Drive + print metrics

# %%
import json
# !cp -r ./experiments/$EXP_ID/* $DRIVE_EXP_PATH/

with open(f'./experiments/{EXP_ID}/metrics.json') as f:
    m = json.load(f)

print(f'\n=== {EXP_ID} Results ===')
print(f"Loss (val)   : {m['loss']:.4f}")
print()
print("             MAE      RMSE      R2")
print(f"  food     : {m['mae_food']:.4f}   {m['rmse_food']:.4f}   {m['r2_food']:.4f}")
print(f"  price    : {m['mae_price']:.4f}   {m['rmse_price']:.4f}   {m['r2_price']:.4f}")
print(f"  atmos    : {m['mae_atmos']:.4f}   {m['rmse_atmos']:.4f}   {m['r2_atmos']:.4f}")
print(f"  service  : {m['mae_service']:.4f}   {m['rmse_service']:.4f}   {m['r2_service']:.4f}")
print(f"  overall  : {m['mae_overall']:.4f}   {m['rmse_overall']:.4f}   {m['r2_overall']:.4f}")
print()
print(f"  mean_mae   : {m['mean_mae']:.4f}")
print(f"  aspect_mae : {m['aspect_mae']:.4f}")
print(f"  overall_mae: {m['overall_mae']:.4f}")
# Out:
# === EXP_051D_bestfusion_uncertaintyweighted Results ===
# Loss (val)   : 2.1737
#
#              MAE      RMSE      R2
#   food     : 1.1024   1.4885   0.5790
#   price    : 1.1727   1.5632   0.4529
#   atmos    : 1.1742   1.5175   0.4067
#   service  : 1.1764   1.5623   0.5240
#   overall  : 0.9144   1.2213   0.6337
#
#   mean_mae   : 1.1080
#   aspect_mae : 1.1564
#   overall_mae: 0.9144
