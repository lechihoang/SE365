# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 13004, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 13004 (delta 126), reused 170 (delta 69), pack-reused 12774 (from 1)
# Receiving objects: 100% (13004/13004), 867.87 MiB | 52.33 MiB/s, done.
# Resolving deltas: 100% (157/157), done.
# /kaggle/working/SE365
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 104.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# ...

# %%
# !python main.py --mode train_text --epochs 5 --lr 1e-5 --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image --text_model_name microsoft/mdeberta-v3-base
# Out:
# ====== MODE: TRAIN_TEXT ======
# Using device: cuda
# config.json: 100%|█████████████████████████████| 579/579 [00:00<00:00, 2.93MB/s]
# ...
# tokenizer_config.json: 100%|██████████████████| 52.0/52.0 [00:00<00:00, 296kB/s]
# spm.model: 100%|███████████████████████████| 4.31M/4.31M [00:00<00:00, 18.1MB/s]
# preprocessor_config.json: 100%|████████████████| 266/266 [00:00<00:00, 1.76MB/s]
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Dataset...
# Đã nạp 4000 mẫu cho Train và 500 mẫu cho Val
# Initializing Model...
# pytorch_model.bin: 100%|████████████████████| 1.33G/1.33G [00:08<00:00, 162MB/s]
# model.safetensors:   0%|                            | 0.00/1.33G [00:00<?, ?B/s]
# ...

# %%
# !python main.py --mode train_image --epochs 10 --lr 5e-6 --weight_decay 0.05 --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image --image_model_name vit_base_patch16_siglip_224
# Out:
# ====== MODE: TRAIN_IMAGE ======
# Using device: cuda
# ...
# config.json: 100%|█████████████████████████████| 615/615 [00:00<00:00, 2.32MB/s]
# tokenizer_config.json: 100%|██████████████████| 25.0/25.0 [00:00<00:00, 188kB/s]
# sentencepiece.bpe.model: 100%|█████████████| 5.07M/5.07M [00:00<00:00, 14.8MB/s]
# tokenizer.json: 9.10MB [00:00, 21.4MB/s]
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Dataset...
# Đã nạp 4000 mẫu cho Train và 500 mẫu cho Val
# Initializing Model...
# model.safetensors: 100%|█████████████████████| 372M/372M [00:04<00:00, 87.9MB/s]
# Epoch 1/10: 100%|██████████████████| 250/250 [05:28<00:00,  1.31s/it, loss=1.49]
#
# Epoch 1/10 | Train Loss: 14.1668 | Val Loss: 2.9917
# ...

# %%
# !python main.py --mode train_fusion --epochs 15 --lr 1e-4 --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image --text_model_name microsoft/mdeberta-v3-base --image_model_name vit_base_patch16_siglip_224
# Out:
# ====== MODE: TRAIN_FUSION ======
# Using device: cuda
# ...
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Dataset...
# Đã nạp 4000 mẫu cho Train và 500 mẫu cho Val
# Initializing Model...
# Loading weights: 100%|█| 198/198 [00:00<00:00, 2593.07it/s, Materializing param=
# DebertaV2Model LOAD REPORT from: microsoft/mdeberta-v3-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# lm_predictions.lm_head.dense.bias          | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight          | UNEXPECTED |  |
# mask_predictions.dense.weight              | UNEXPECTED |  |
# mask_predictions.dense.bias                | UNEXPECTED |  |
# ...

# %%
# !python test.py --mode train_fusion --train_path /kaggle/input/datasets/lchhong/multimodal/data/text/train.csv --val_path /kaggle/input/datasets/lchhong/multimodal/data/text/val.csv --test_path /kaggle/input/datasets/lchhong/multimodal/data/text/test.csv --image_dir /kaggle/input/datasets/lchhong/multimodal/data/image --text_model_name microsoft/mdeberta-v3-base --image_model_name vit_base_patch16_siglip_224
# Out:
# ====== TESTING MODE: TRAIN_FUSION ======
# ...
# The image processor of type `ConvNextImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Loading Test Dataset...
# Đã nạp 500 mẫu Test
# Loading weights: 100%|█| 198/198 [00:00<00:00, 2324.18it/s, Materializing param=
# DebertaV2Model LOAD REPORT from: microsoft/mdeberta-v3-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# mask_predictions.dense.bias                | UNEXPECTED |  |
# mask_predictions.LayerNorm.weight          | UNEXPECTED |  |
# mask_predictions.dense.weight              | UNEXPECTED |  |
# mask_predictions.classifier.bias           | UNEXPECTED |  |
# mask_predictions.classifier.weight         | UNEXPECTED |  |
# ...
