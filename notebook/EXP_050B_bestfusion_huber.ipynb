# %% [markdown]
# # EXP_050B — Robust Loss: Huber
# **Phase 5 | Loss Ablation**
# Research question: Does Huber loss handle outliers better than MSE?
# - Loss: `huber` | Best Fusion from Phase 4 | Seed: 42 | AMP: enabled
# > ⚠️ Set BEST_FUSION_TYPE, BEST_IMAGE_MODEL, BEST_TEXT_MODEL in STEP 4.

# %% [markdown]
# ### STEP 1: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### STEP 2: Clone source code and install dependencies

# %%
# !git clone https://github.com/lechihoang/SE365.git
# %cd SE365
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 13393, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 13393 (delta 193), reused 173 (delta 105), pack-reused 13129 (from 1)
# Receiving objects: 100% (13393/13393), 873.22 MiB | 35.76 MiB/s, done.
# Resolving deltas: 100% (431/431), done.
# /content/SE365

# %% [markdown]
# ### STEP 3: Download and extract data

# %%
# !rm -rf ./data
# !cp /content/drive/MyDrive/SE365/data.zip ./data.zip
# !unzip -q data.zip
# !rm data.zip
# !ls -la ./data
# Out:
# total 1416
# drwxr-xr-x  4 root root    4096 Jun 16 09:21 .
# drwxr-xr-x 11 root root    4096 Jun 23 17:57 ..
# drwxr-xr-x  2 root root 1437696 Jun 16 09:59 image
# drwxr-xr-x  2 root root    4096 Jun 16 09:21 text

# %% [markdown]
# ### STEP 4: Configure paths — ✏️ Set Phase 2, 3, 4 winners here

# %%
import os
DRIVE_ROOT = '/content/drive/MyDrive/SE365'  # ✏️ Change if needed
EXP_ID = 'EXP_050B_bestfusion_huber'

BEST_IMAGE_MODEL  = 'swin_base_patch4_window7_224'   # ✏️ Phase 2 winner
BEST_TEXT_MODEL   = 'vinai/phobert-base-v2'           # ✏️ Phase 3 winner
BEST_FUSION_TYPE  = 'cross_attention'                             # ✏️ Phase 4 winner (concat/gmu/gated_cross/film/cross_attention)
BEST_IMAGE_EXP_ID = 'EXP_020B_swinb_xlmr_concat_mse'
BEST_TEXT_EXP_ID  = 'EXP_030B_bestimage_phobert_concat_mse'

DRIVE_EXP_PATH = f'{DRIVE_ROOT}/experiments/{EXP_ID}'
os.makedirs(DRIVE_EXP_PATH, exist_ok=True)
print(f'Artifacts: {DRIVE_EXP_PATH}')
print(f'Fusion: {BEST_FUSION_TYPE} | Image: {BEST_IMAGE_MODEL} | Text: {BEST_TEXT_MODEL}')
# Out:
# Artifacts: /content/drive/MyDrive/SE365/experiments/EXP_050B_bestfusion_huber
# Fusion: cross_attention | Image: swin_base_patch4_window7_224 | Text: vinai/phobert-base-v2

# %% [markdown]
# ### STEP 5: Load pretrained weights

# %%
import os, shutil
os.makedirs('./checkpoints', exist_ok=True)
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_TEXT_EXP_ID}/best_model_train_text.pth', './checkpoints/best_model_train_text.pth')
print(f'Loaded text from {BEST_TEXT_EXP_ID}')
shutil.copy(f'{DRIVE_ROOT}/experiments/{BEST_IMAGE_EXP_ID}/best_model_train_image.pth', './checkpoints/best_model_train_image.pth')
print(f'Loaded image from {BEST_IMAGE_EXP_ID}')
# Out:
# Loaded text from EXP_030B_bestimage_phobert_concat_mse
# Loaded image from EXP_020B_swinb_xlmr_concat_mse

# %% [markdown]
# ### STEP 6: Train

# %%
# !python main.py \
  --mode train_fusion \
  --fusion_type {BEST_FUSION_TYPE} \
  --text_model_name {BEST_TEXT_MODEL} \
  --image_model_name {BEST_IMAGE_MODEL} \
  --epochs 15 \
  --batch_size 16 \
  --lr 1e-5 \
  --grad_accum_steps 2 \
  --patience 5 \
  --loss_fn huber \
  --unfreeze_text_layers 1 \
  --unfreeze_image_layers 1 \
  --seed 42 \
  --use_amp \
  --exp_id EXP_050B_bestfusion_huber \
  --exp_dir ./experiments
# Out:
# ====== MODE: TRAIN_FUSION ======
# Using device: cuda
# Seed: 42 | Experiment: EXP_050B_bestfusion_huber
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 678/678 [00:00<00:00, 3.30MB/s]
# vocab.txt: 100% 895k/895k [00:00<00:00, 56.7MB/s]
# bpe.codes: 100% 1.14M/1.14M [00:00<00:00, 140MB/s]
# tokenizer.json: 100% 3.13M/3.13M [00:00<00:00, 137MB/s]
# Loaded timm processor for swin_base_patch4_window7_224
# pytorch_model.bin: 100% 540M/540M [00:03<00:00, 153MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 17859.68it/s]
# [transformers] RobertaModel LOAD REPORT from: vinai/phobert-base-v2
# Key                       | Status     |
# --------------------------+------------+-
# lm_head.bias              | UNEXPECTED |
# lm_head.layer_norm.bias   | UNEXPECTED |
# lm_head.dense.bias        | UNEXPECTED |
# lm_head.dense.weight      | UNEXPECTED |
# lm_head.layer_norm.weight | UNEXPECTED |
# pooler.dense.weight       | MISSING    |
# pooler.dense.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors:   0% 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/540M [00:01<?, ?B/s]
# model.safetensors:  12% 67.2M/540M [00:01<00:00, 669MB/s]
# model.safetensors:   0% 0.00/353M [00:01<?, ?B/s]
# model.safetensors:  75% 403M/540M [00:02<00:00, 513MB/s]
# model.safetensors:  12% 43.5M/353M [00:01<00:04, 62.2MB/s]
# model.safetensors:  14% 47.7M/353M [00:01<00:05, 58.6MB/s]
# model.safetensors:  46% 161M/353M [00:01<00:00, 274MB/s]
# model.safetensors: 100% 540M/540M [00:02<00:00, 430MB/s]
# model.safetensors:  75% 265M/353M [00:02<00:00, 369MB/s]
# model.safetensors: 100% 540M/540M [00:03<00:00, 157MB/s]
# model.safetensors: 100% 353M/353M [00:02<00:00, 133MB/s]
# /content/SE365/Trainer.py:88: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.use_amp)
# 2026-06-23 17:59:22 ====== START: 2026-06-23T17:59:22.631811 ======
# 2026-06-23 17:59:22 Experiment: EXP_050B_bestfusion_huber | Mode: train_fusion | exp_dir: ./experiments/EXP_050B_bestfusion_huber
# Epoch 1/15:   0% 0/300 [00:00<?, ?it/s]/content/SE365/Trainer.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# Epoch 1/15: 100% 300/300 [04:44<00:00,  1.06it/s, loss=5.97, lr=6.67e-6]
# /content/SE365/Trainer.py:157: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.use_amp):
# 2026-06-23 18:04:50 Epoch 1/15 | Train Loss: 6.5413 | Val Loss: 5.9355 | Mean MAE: 6.4147
# 2026-06-23 18:04:50   -> MAE  | Food: 6.9393 | Price: 6.3507 | Atmos: 6.1028 | Service: 6.3338 | Overall: 6.3468
# 2026-06-23 18:04:50   -> RMSE | Food: 7.3038 | Price: 6.6856 | Atmos: 6.4053 | Service: 6.7190 | Overall: 6.6452
# 2026-06-23 18:04:50   -> R2   | Food: -9.1356 | Price: -9.0073 | Atmos: -9.5716 | Service: -7.8049 | Overall: -9.8450
# 2026-06-23 18:04:52 *** Saved best model to ./experiments/EXP_050B_bestfusion_huber/best_model_train_fusion.pth (mean_mae
./experiments/EXP_050B_bestfusion_huber/best_model_train_fusion.pth (mean_mae=1.1085) ***
# Epoch 11/15: 100% 300/300 [04:52<00:00,  1.03it/s, loss=0.43, lr=2.01e-6]
# 2026-06-23 18:59:25 Epoch 11/15 | Train Loss: 0.6466 | Val Loss: 0.7172 | Mean MAE: 1.1142
# 2026-06-23 18:59:25   -> MAE  | Food: 1.1262 | Price: 1.1729 | Atmos: 1.1750 | Service: 1.1790 | Overall: 0.9178
# 2026-06-23 18:59:25   -> RMSE | Food: 1.5233 | Price: 1.5741 | Atmos: 1.5294 | Service: 1.5749 | Overall: 1.2319
# 2026-06-23 18:59:25   -> R2   | Food: 0.5591 | Price: 0.4453 | Atmos: 0.3973 | Service: 0.5162 | Overall: 0.6273
# 2026-06-23 18:59:25 No improvement for 1/5 epoch(s).
# Epoch 12/15: 100% 300/300 [05:19<00:00,  1.07s/it, loss=0.946, lr=1.17e-6]
# 2026-06-23 19:05:27 Epoch 12/15 | Train Loss: 0.6463 | Val Loss: 0.7138 | Mean MAE: 1.1095
# 2026-06-23 19:05:27   -> MAE  | Food: 1.1119 | Price: 1.1725 | Atmos: 1.1734 | Service: 1.1754 | Overall: 0.9142
# 2026-06-23 19:05:27   -> RMSE | Food: 1.5087 | Price: 1.5738 | Atmos: 1.5270 | Service: 1.5701 | Overall: 1.2289
# 2026-06-23 19:05:27   -> R2   | Food: 0.5675 | Price: 0.4455 | Atmos: 0.3992 | Service: 0.5192 | Overall: 0.6291
# 2026-06-23 19:05:27 No improvement for 2/5 epoch(s).
# Epoch 13/15: 100% 300/300 [04:52<00:00,  1.03it/s, loss=0.719, lr=5.32e-7]
# 2026-06-23 19:11:00 Epoch 13/15 | Train Loss: 0.6565 | Val Loss: 0.7164 | Mean MAE: 1.1133
# 2026-06-23 19:11:00   -> MAE  | Food: 1.1218 | Price: 1.1735 | Atmos: 1.1751 | Service: 1.1784 | Overall: 0.9179
# 2026-06-23 19:11:00   -> RMSE | Food: 1.5189 | Price: 1.5760 | Atmos: 1.5298 | Service: 1.5734 | Overall: 1.2311
# 2026-06-23 19:11:00   -> R2   | Food: 0.5617 | Price: 0.4439 | Atmos: 0.3970 | Service: 0.5171 | Overall: 0.6278
# 2026-06-23 19:11:00 No improvement for 3/5 epoch(s).
# Epoch 14/15: 100% 300/300 [04:55<00:00,  1.01it/s, loss=0.687, lr=1.35e-7]
# 2026-06-23 19:16:27 Epoch 14/15 | Train Loss: 0.6474 | Val Loss: 0.7145 | Mean MAE: 1.1107
# 2026-06-23 19:16:27   -> MAE  | Food: 1.1165 | Price: 1.1719 | Atmos: 1.1744 | Service: 1.1760 | Overall: 0.9149
# 2026-06-23 19:16:27   -> RMSE | Food: 1.5133 | Price: 1.5729 | Atmos: 1.5289 | Service: 1.5706 | Overall: 1.2289
# 2026-06-23 19:16:27   -> R2   | Food: 0.5649 | Price: 0.4461 | Atmos: 0.3977 | Service: 0.5189 | Overall: 0.6291
# 2026-06-23 19:16:27 No improvement for 4/5 epoch(s).
# Epoch 15/15: 100% 300/300 [04:49<00:00,  1.04it/s, loss=0.642, lr=0]
# 2026-06-23 19:21:52 Epoch 15/15 | Train Loss: 0.6591 | Val Loss: 0.7154 | Mean MAE: 1.1118
# 2026-06-23 19:21:52   -> MAE  | Food: 1.1185 | Price: 1.1726 | Atmos: 1.1746 | Service: 1.1771 | Overall: 0.9162
# 2026-06-23 19:21:52   -> RMSE | Food: 1.5156 | Price: 1.5740 | Atmos: 1.5293 | Service: 1.5723 | Overall: 1.2302
# 2026-06-23 19:21:52   -> R2   | Food: 0.5636 | Price: 0.4453 | Atmos: 0.3974 | Service: 0.5179 | Overall: 0.6283
# 2026-06-23 19:21:52 No improvement for 5/5 epoch(s).
# 2026-06-23 19:21:52 Early stopping triggered after 15 epochs!
# 2026-06-23 19:21:52 ====== Final evaluation with best checkpoint ======
# 2026-06-23 19:21:53 Loaded best checkpoint from ./experiments/EXP_050B_bestfusion_huber/best_model_train_fusion.pth
# 2026-06-23 19:22:28 Final Val Loss: 0.7127 | Mean MAE: 1.1085
# 2026-06-23 19:22:28 Metrics saved to ./experiments/EXP_050B_bestfusion_huber/metrics.json
# 2026-06-23 19:22:28 Predictions saved to ./experiments/EXP_050B_bestfusion_huber/predictions.csv
# 2026-06-23 19:22:28 ====== END: 2026-06-23T19:22:28.286094 ======

# %% [markdown]
# ### STEP 7: Save to Drive + print metrics

# %%
import json
# !cp -r ./experiments/$EXP_ID/* $DRIVE_EXP_PATH/

with open(f'./experiments/{EXP_ID}/metrics.json') as f:
    m = json.load(f)

print(f'\n=== {EXP_ID} Results ===')
print(f"Loss (val)   : {m['loss']:.4f}")
print()
print("             MAE      RMSE      R2")
print(f"  food     : {m['mae_food']:.4f}   {m['rmse_food']:.4f}   {m['r2_food']:.4f}")
print(f"  price    : {m['mae_price']:.4f}   {m['rmse_price']:.4f}   {m['r2_price']:.4f}")
print(f"  atmos    : {m['mae_atmos']:.4f}   {m['rmse_atmos']:.4f}   {m['r2_atmos']:.4f}")
print(f"  service  : {m['mae_service']:.4f}   {m['rmse_service']:.4f}   {m['r2_service']:.4f}")
print(f"  overall  : {m['mae_overall']:.4f}   {m['rmse_overall']:.4f}   {m['r2_overall']:.4f}")
print()
print(f"  mean_mae   : {m['mean_mae']:.4f}")
print(f"  aspect_mae : {m['aspect_mae']:.4f}")
print(f"  overall_mae: {m['overall_mae']:.4f}")
# Out:
# === EXP_050B_bestfusion_huber Results ===
# Loss (val)   : 0.7127
#
#              MAE      RMSE      R2
#   food     : 1.1097   1.5054   0.5694
#   price    : 1.1685   1.5671   0.4501
#   atmos    : 1.1734   1.5261   0.3999
#   service  : 1.1779   1.5722   0.5179
#   overall  : 0.9131   1.2261   0.6308
#
#   mean_mae   : 1.1085
#   aspect_mae : 1.1574
#   overall_mae: 0.9131
